# %% [markdown]
# ## Automated HPC Log Analysis & Error Resolution System - analysis

# %%
import pandas as pd
import re
import requests
from ydata_profiling import ProfileReport
import io
import gzip

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load dataset

# %%
# Fetch log file from GitHub
log_url = "https://raw.githubusercontent.com/orsho/HPC-Log-Resolution/main/data/HPC.log"
response = requests.get(log_url)
log_lines = response.text.split("\n")  # Split into lines

log_data = []

# Parse logs using regex
for line in log_lines:
    match = re.match(r'(\d+) (\S+) (\S+) (\S+) (\d+) (\d+) (.+)', line.strip())
    if match:
        log_data.append(match.groups())

# Convert to DataFrame
columns = ["ID", "Node", "Subsystem", "Event", "Timestamp", "Unknown", "Message"]
log_df = pd.DataFrame(log_data, columns=columns)
log_df["Timestamp"] = pd.to_datetime(log_df["Timestamp"].astype(int), unit="s", errors="coerce")

print(log_df.shape)
log_df.head()
# Out:
# (430225, 7)
#         ID      Node Subsystem                     Event           Timestamp  \
# 0  2557285  node-233   unix.hw  state_change.unavailable 2004-01-01 08:32:01
# 1  2562603  node-233   unix.hw  state_change.unavailable 2004-01-08 08:34:05
# 2  2561225  node-228   unix.hw  state_change.unavailable 2004-01-06 07:25:07
# 3  2598209  node-ms0   unix.hw  state_change.unavailable 2004-01-16 22:14:33
# 4  2598216  node-ms0   unix.hw  state_change.unavailable 2004-01-16 22:19:30
#
#   Unknown                                            Message
# 0       1  Component State Change: Component \042alt0\042...
# 1       1  Component State Change: Component \042alt0\042...
# 2       1  Component State Change: Component \042alt0\042...
# 3       1  Component State Change: Component \042alt0\042...
# 4       1  Component State Change: Component \042alt0\042...

# %%
# Sample the DataFrame
# df_sample = log_df.sample(frac=0.1, random_state=42)
# profile = ProfileReport(df_sample, title="Data Profiling Report", explorative=True)
# profile.to_file("1_log_profiling.html") # open "1_log_profiling.html" file if you can't see the iframe
# profile.to_notebook_iframe()

# %% [markdown]
# #### Load results (processed file with resolution)

# %%
# GitHub raw file URL (compressed CSV)
csv_url = "https://raw.githubusercontent.com/orsho/HPC-Log-Resolution/main/results/processed_logs.csv.gz"
response = requests.get(csv_url, verify=False)

# Decompress and load CSV into pandas
with gzip.GzipFile(fileobj=io.BytesIO(response.content), mode="rb") as f:
    logs_with_resolutions = pd.read_csv(f)

# Display shape and preview
print(logs_with_resolutions.shape)
logs_with_resolutions.head()
# Out:
# (430225, 9)
#         ID      Node Subsystem                     Event            Timestamp  \
# 0  2557285  node-233   unix.hw  state_change.unavailable  2004-01-01 08:32:01
# 1  2562603  node-233   unix.hw  state_change.unavailable  2004-01-08 08:34:05
# 2  2561225  node-228   unix.hw  state_change.unavailable  2004-01-06 07:25:07
# 3  2598209  node-ms0   unix.hw  state_change.unavailable  2004-01-16 22:14:33
# 4  2598216  node-ms0   unix.hw  state_change.unavailable  2004-01-16 22:19:30
#
#    Unknown                                            Message log_level  \
# 0        1  Component State Change: Component \042alt0\042...     ERROR
# 1        1  Component State Change: Component \042alt0\042...     ERROR
# 2        1  Component State Change: Component \042alt0\042...     ERROR
# 3        1  Component State Change: Component \042alt0\042...     ERROR
# 4        1  Component State Change: Component \042alt0\042...     ERROR
#
#                                     Resolution_Steps
# 0  **Issue Summary:**\nThe HPC system has reporte...
# 1  **Issue Summary:**\nThe HPC system has reporte...
# 2  Here is my analysis and suggested remediation ...
# 3  Here is my analysis and suggested remediation ...
# 4  Here is my analysis and suggested remediation ...

# %% [markdown]
# #### Sample 2 random error messages and print in a formatted way

# %%
sample_size = min(2, len(logs_with_resolutions[logs_with_resolutions["log_level"] == "ERROR"]))
sampled_errors = logs_with_resolutions[logs_with_resolutions["log_level"] == "ERROR"].sample(n=sample_size, random_state=42)

for _, row in sampled_errors.iterrows():
    print("\nSample Error Logs with Resolutions:\n" + "=" * 80)
    print(f"Log Message: {row['Message']}\n")
    print(f"Suggested Resolution: {row['Resolution_Steps']}\n")
# Out:
# 🔍 Sample Error Logs with Resolutions:
# ================================================================================
# Log Message: Linkerror event interval expired
#
# Suggested Resolution: **Issue Summary:**
# The 'Linkerror event interval expired' error message indicates a timeout issue in the high-performance computing (HPC) system, suggesting that a link error event was not resolved within the expected time interval, resulting in a system failure or instability.
#
# **Possible Causes:**
#
# - **InfiniBand (IB) fabric issues**: The IB fabric might be experiencing congestion, packet loss, or faulty cables, leading to link errors that are not resolved within the expected time interval.
# - **Node or switch hardware failures**: A faulty node or switch in the cluster can cause link errors, which may not be resolved within the expected time interval, triggering the error message.
# - **Configuration issues**: Misconfigured IB settings, such as incorrect subnet manager configurations or invalid MTU settings, can lead to link errors and timeouts.
# - **Software bugs or version incompatibilities**: Bugs in the IB driver or firmware, or incompatibilities between the IB driver and firmware versions, can cause link errors that are not resolved within the expected time interval.
#
# **Resolution Steps:**
#
# 1. **Check IB fabric health**:
# 	* Run `ibv_devices` and `ibv_ports` commands to verify the IB fabric topology and identify any faulty nodes or switches.
# 	* Use `iblinkinfo` to check the link quality and identify any errors or congestion.
# 2. **Investigate node and switch hardware**:
# 	* Check the system event logs for any hardware error messages or warnings.
# 	* Perform a visual inspection of the IB cables and connectors to ensure they are securely connected.
# 3. **Verify IB configuration**:
# 	* Check the IB subnet manager configuration using `ibv_sm` or `opensm` commands.
# 	* Verify the MTU settings using `ibv_devinfo` command.
# 4. **Update IB driver and firmware**:
# 	* Check the IB driver and firmware versions using `ibv_devinfo` or `ibv_fw_version` commands.
# 	* Update the IB driver and firmware to the latest versions, if necessary.
# 5. **Restart IB services and subnet manager**:
# 	* Restart the IB services and subnet manager to ensure that any changes take effect.
# 6. **Monitor system logs and IB fabric**:
# 	* Closely monitor the system logs and IB fabric health to ensure that the issue is resolved and does not recur.
#
# By following these resolution steps, you should be able to identify and resolve the underlying cause of the 'Linkerror event interval expired' error, ensuring the stability and performance of your HPC system.
#
#
# 🔍 Sample Error Logs with Resolutions:
# ================================================================================
# Log Message: link errors remain current
#
# Suggested Resolution: Here's my analysis and suggested remediation steps for the HPC error log message "link errors remain current":
#
# **Issue Summary:**
# The HPC system is experiencing issues with link errors, which are preventing the system from functioning correctly. The error message "link errors remain current" indicates that the errors are persistent and notbeing resolved.
#
# **Possible Causes:**
#
# * InfiniBand (IB) or Omni-Path (OPA) fabric issues, such as faulty cables, switches, or nodes
# * Misconfigured subnet manager (SM) or network configuration
# * Firmware or software issues with the IB or OPA adapters
# * Node or switch hardware failures
# * Insufficient resource allocation (e.g., buffers, credits) for the IB or OPA fabric
# * Software or application issues, such as incorrect library versions or dependencies
#
# **Resolution Steps:**
#
# 1. **Gather more information**: Run the `ibv_devinfo` command to gather detailed information about the IB or OPA adapters, including firmware and software versions. Also, review the system logs for any additional error messages that may provide more context.
# 2. **Check cable connections and switch configurations**: Verify that all cables are securely connected and that the switches are properly configured. Ensure that the subnet manager (SM) is correctly configured and running.
# 3. **Run diagnostic tests**: Use tools like `ibdiagnet` or `opa_diag` to run diagnostic tests on the IB or OPA fabric. These tools can help identify issues with the fabric, such as faulty cables or switches.
# 4. **Update firmware and software**: Ensure that the IB or OPA adapters have the latest firmware and software updates installed. Consult the vendor documentation for instructions on how to update the firmware and software.
# 5. **Check resource allocation**: Verify that sufficient resources (e.g., buffers, credits) are allocated for the IB or OPA fabric. Consult the system documentation for guidance on allocating resources.
# 6. **Investigate software or application issues**: If none of the above steps resolve the issue, investigate software or application issues, such as incorrect library versions or dependencies. Consult the application documentation and vendor support resources for assistance.
# 7. **Consult system logs and monitoring tools**: Monitor system logs and use tools like `ganglia` or `Nagios` to monitor system performance and identify any patterns or trends that may indicate the root cause of the issue.
# 8. **Contact vendor support**: If none of the above steps resolve the issue, contact the vendor support for further assistance and guidance. They may be able to provide additional troubleshooting steps or repair/replace faulty hardware components.
#
# By following these steps, you should be able to identify and resolve the underlying cause of the "link errors remain current" issue in your HPC system.

# %% [markdown]
# #### Basic info from the processed results

# %%
# Total messages (not unique)
total_messages = len(logs_with_resolutions)

# Total ERROR messages (not unique)
total_errors = (logs_with_resolutions["log_level"] == "ERROR").sum()

# Unique messages
unique_messages = logs_with_resolutions["Message"].nunique()

# Unique ERROR messages
unique_error_messages = logs_with_resolutions[logs_with_resolutions["log_level"] == "ERROR"]["Message"].nunique()

# Compute ratios
error_ratio_total = total_errors / total_messages if total_messages > 0 else 0
error_ratio_unique = unique_error_messages / unique_messages if unique_messages > 0 else 0

# Print results
print(f"Log Message Statistics:\n" + "-" * 40)
print(f"Total Messages (incl. duplicates): {total_messages}")
print(f"Total ERROR Messages: {total_errors}")
print(f"Error Ratio (Total): {error_ratio_total:.2%}\n")

print(f"Unique Messages: {unique_messages}")
print(f"Unique ERROR Messages: {unique_error_messages}")
print(f"Error Ratio (Unique): {error_ratio_unique:.2%}")
# Out:
# Log Message Statistics:
# ----------------------------------------
# Total Messages (incl. duplicates): 430225
# Total ERROR Messages: 145029
# Error Ratio (Total): 33.71%
#
# Unique Messages: 9961
# Unique ERROR Messages: 3369
# Error Ratio (Unique): 33.82%
